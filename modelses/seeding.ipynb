# %%
import pandas as pd
from sqlalchemy.orm import Session

# %%
pegawai = pd.read_csv("seed/DataPegawai.csv")

# %%
pegawai.tail()
# Out:
#       IdPegawai  KdJenisPegawai  KdTitle            NamaLengkap NamaKeluarga  \
# 761  L001000068               7      4.0  IRKHAM ABDULLAH AZZAM          NaN
# 762  P023000575              23      2.0           Santoso, Amd          NaN
# 763  P023000576              23      2.0              Ayub, Amd          NaN
# 764  P023000577              23      2.0         Dwi Setyo, Amd          NaN
# 765  P023000578              23      2.0         Trisnanto, Amd          NaN
#
#     NamaPanggilan JenisKelamin TempatLahir           TglLahir TglMasuk  \
# 761           NaN            L       Tegal  7/8/1992 00:00:00      NaN
# 762           NaN          NaN         NaN                NaN      NaN
# 763           NaN          NaN         NaN                NaN      NaN
# 764           NaN          NaN         NaN                NaN      NaN
# 765           NaN          NaN         NaN                NaN      NaN
#
#     TglKeluar
# 761       NaN
# 762       NaN
# 763       NaN
# 764       NaN
# 765       NaN

# %%
pgw_new = pegawai.drop(["KdJenisPegawai", "KdTitle", "TglMasuk", "TglKeluar"], axis=1)

# %%
pgw_new.to_csv()
# Out:
#       IdPegawai                                      NamaLengkap  \
# 0    8888888888                                   Staff/Karyawan
# 1    L013000001                           dr. WASRIL WAZAR, SpJp
# 2    P013000002                             dr. INDRIANA BUDIONO
# 3    L013000003                      dr. IZZUDIN DS, Sp.KJ.M.Kes
# 4    L013000004                 dr. ABDAL HAKIM TOHARI, SpRM.MMR
# 5    P013000005                           dr. JOHANA JONO SEWOJO
# 6    L013000006                           dr. ALIP ASMADI, SpRad
# 7    P013000007                  dr. ENDANG TUNGGAL DEWI HOETOMO
# 8    P013000008                         dr. ERLINA KRISANTI, Msi
# 9    P013000009            Dra. NIKEN TRI WIDJAJANING KOESWINATI
# 10   P013000010                dr. SRI PRIMAWATI INDRASWARI,SpKK
# 11   L013000011              dr. Irawan Eko Boedjo Margono, Sp B
# 12   L013000013                            dr. Probodjati, Sp OT
# 13   P013000014                               Dra. SITI ZUBAEDAH
# 14   L013000015                          dr. RADEN SETIYADI, SpA
# 15   P013000016               SUSILOWATI MARYANING ASTUTI, S.Kep
# 16   L013000017                             drg. SOEKAMTO, Sp.BM
# 17   L013000018                                dr. PARJITO, SpOG
# 18   L013000019                           dr. SAID BARABA, Sp.PD
# 19   L013000020                                 dr. SUNARTO, SpS
# 20   P013000021                                     SRI ATUN, SH
# 21   P013000022                         WIWIN AGUSTIYANI, SH,MSi
# 22   L013000023                            dr. HERY SUSANTO, SpA
# 23   L013000024                                     SAENI, S.Kep
# 24   P013000025                           ETY RAHMAWATI, Amk.Keb
# 25   P013000026                     SRI HARTIYANTI WIDAYATI, Amk
# 26   P013000027                         TUTI RUSIATININGSIH, Amk
# 27   P013000028                           Dra. TITI SULISTYOWATI
# 28   P013000029                                      N M SURTINI
# 29   P013000030                                       AFIAH, Amk
# ..          ...                                              ...
# 736  L007000610                                    DONI ZULFIKAR
# 737  L002000647                                    Ade hariyanto
# 738  L007000653                               RIZAL ADHI SAPUTRA
# 739  P007000654                              DWI NITA PANGESTIKA
# 740  P007000657                                   DEWI SUSIYANTI
# 741  P007000660                                  ALVIANA NURUL A
# 742  L001000676  dr.DODY SUHARTONO, SpKK/dr. Nadiah, Sp.KK,M.Kes
# 743  P007000688                                Diana Eka Kartika
# 744  L007000689                                M. Andi Ardiyanto
# 745  P023000542                          dr. Rizal Irvanda, Sp.M
# 746  L007000691                             Gilang Gusti Permana
# 747  P007000692                                  Anisa Nurjannah
# 748  P002000694                               Rezza Dian Pratiwi
# 749  P023000556                       dr. Nurbaiti, SP.T.H.T.K.L
# 750  3333333333                               Pendaftaran Online
# 751  P023000562                                 Afriandi Baihaqi
# 752  P023000563                                     Didi Isnaini
# 753  P023000569                                    Dian Nursandi
# 754  P023000565                                     Uly Rosdiana
# 755  P023000570                                 Akhmad Syaefudin
# 756  P023000567                                    Hibah Sugesti
# 757  P023000568                              Arini Nur Saofiyani
# 758  P023000571                                    Akhmad Waluyo
# 759  P023000572                       Defi Anjar Sari, Amd. Farm
# 760  P023000573                       Ila Ubaidillah Dhofar, Amd
# 761  L001000068                            IRKHAM ABDULLAH AZZAM
# 762  P023000575                                     Santoso, Amd
# 763  P023000576                                        Ayub, Amd
# 764  P023000577                                   Dwi Setyo, Amd
# 765  P023000578                                   Trisnanto, Amd
#
#               NamaKeluarga          NamaPanggilan JenisKelamin  TempatLahir  \
# 0                      NaN                    NaN            L          NaN
# 1                      NaN                    NaN            L      Jakarta
# 2                      NaN                    NaN            P        Tegal
# 3                      NaN                    NaN            L   Pekalongan
# 4                      NaN                    NaN            L      Nganjuk
# 5                      NaN                    NaN            P      Jakarta
# 6                      NaN  19600419 198701 1 002            L       Batang
# 7                      NaN  19610108 198802 2 001            P       Madiun
# 8                      NaN                    NaN            P  Probolinggo
# 9                      NaN                    NaN            P     Surabaya
# 10                     NaN                    NaN            P     Surabaya
# 11                     NaN  19600521 198802 1 001            L     Boyolali
# 12                     NaN                    NaN            L      Jakarta
# 13                     NaN                    NaN            P        Tegal
# 14                     NaN  19600606 198512 1 005            L    Purworejo
# 15                     NaN                    NaN            P   Temanggung
# 16                     NaN                    NaN            L     Magelang
# 17   19620713 198911 1 001  19620713 198911 1 001            L       Bantul
# 18                     NaN  19680521 199703 1 002            L        Tegal
# 19                     NaN                    NaN            L       Sragen
# 20                     NaN                    NaN            P     Pemalang
# 21                     NaN                    NaN            P     Semarang
# 22                     NaN  19640926 199509 1 001            L     Boyolali
# 23                     NaN                    NaN            L       Kendal
# 24                     NaN                    NaN            P     Majalaya
# 25                     NaN                    NaN            P   Temanggung
# 26                     NaN                    NaN            P        Tegal
# 27                     NaN                    NaN            P       Brebes
# 28                     NaN                    NaN            P       Ciamis
# 29                     NaN                    NaN            P       Brebes
# ..                     ...                    ...          ...          ...
# 736                    NaN                    NaN            L          NaN
# 737                    NaN                    NaN            L          NaN
# 738                    NaN                    NaN            L          NaN
# 739                    NaN                    NaN            P          NaN
# 740                    NaN                    NaN            P          NaN
# 741                    NaN                    NaN            P          NaN
# 742                    NaN                    NaN            L          NaN
# 743                    NaN                    NaN            P     Magelang
# 744                    NaN                    NaN            L        Tegal
# 745                    NaN                    NaN            L          NaN
# 746                    NaN                    NaN            L        Tegal
# 747                    NaN                    NaN            P        Tegal
# 748                    NaN                    NaN            P        Tegal
# 749                    NaN  19800919 200903 2 002            P      Jakarta
# 750                    NaN                    NaN          NaN          NaN
# 751                    NaN                    NaN          NaN          NaN
# 752                    NaN                    NaN          NaN          NaN
# 753                    NaN                    NaN          NaN          NaN
# 754                    NaN                    NaN          NaN          NaN
# 755                    NaN                    NaN          NaN          NaN
# 756                    NaN                    NaN          NaN          NaN
# 757                    NaN                    NaN          NaN          NaN
# 758                    NaN                    NaN          NaN          NaN
# 759                    NaN                    NaN          NaN          NaN
# 760                    NaN                    NaN          NaN          NaN
# 761                    NaN                    NaN            L        Tegal
# 762                    NaN                    NaN          NaN          NaN
# 763                    NaN                    NaN          NaN          NaN
# 764                    NaN                    NaN          NaN          NaN
# 765                    NaN                    NaN          NaN          NaN
#
#                 TglLahir
# 0      1/1/1900 00:00:00
# 1     23/4/1955 00:00:00
# 2    28/11/1954 00:00:00
# 3    15/10/1952 00:00:00
# 4      6/7/1958 00:00:00
# 5     20/7/1955 00:00:00
# 6     19/4/1960 00:00:00
# 7      1/8/1961 00:00:00
# 8    29/12/1963 00:00:00
# 9    20/11/1954 00:00:00
# 10    10/9/1963 00:00:00
# 11   28/11/1954 00:00:00
# 12    31/7/1963 00:00:00
# 13   11/11/1958 00:00:00
# 14     6/6/1960 00:00:00
# 15     3/1/1960 00:00:00
# 16     3/5/1956 00:00:00
# 17    13/7/1962 00:00:00
# 18    21/5/1968 00:00:00
# 19    20/5/1958 00:00:00
# 20    1/10/1962 00:00:00
# 21    17/8/1961 00:00:00
# 22    26/9/1964 00:00:00
# 23    17/1/1965 00:00:00
# 24     6/3/1957 00:00:00
# 25     6/3/1957 00:00:00
# 26   15/12/1960 00:00:00
# 27   25/11/1965 00:00:00
# 28     5/3/1957 00:00:00
# 29     9/1/1959 00:00:00
# ..                   ...
# 736                  NaN
# 737  10/10/1992 00:00:00
# 738                  NaN
# 739                  NaN
# 740                  NaN
# 741                  NaN
# 742                  NaN
# 743    4/5/1980 00:00:00
# 744   29/1/1989 00:00:00
# 745    1/1/1900 00:00:00
# 746                  NaN
# 747                  NaN
# 748                  NaN
# 749                  NaN
# 750                  NaN
# 751                  NaN
# 752                  NaN
# 753                  NaN
# 754                  NaN
# 755                  NaN
# 756                  NaN
# 757                  NaN
# 758                  NaN
# 759                  NaN
# 760                  NaN
# 761    7/8/1992 00:00:00
# 762                  NaN
# 763                  NaN
# 764                  NaN
# 765                  NaN
#
# [766 rows x 7 columns]
